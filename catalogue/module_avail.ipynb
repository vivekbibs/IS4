# %%
import pandas as pd

# %%
modules = pd.read_csv("/shared/projects/mudis4ls_is4_benchmark/IS4_repo/catalogue/module_avail.txt", header=None, sep="\s+")
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\s'
# <>:1: SyntaxWarning: invalid escape sequence '\s'
# /tmp/ipykernel_3215028/1107823381.py:1: SyntaxWarning: invalid escape sequence '\s'
#   modules = pd.read_csv("/shared/projects/mudis4ls_is4_benchmark/IS4_repo/catalogue/module_avail.txt", header=None, sep="\s+")

# %%
modules.rename(columns={0: "module_name", 1: "date",2: "time"}, inplace=True)

# %%
modules
# Out:
#                module_name        date      time
# 0     10x_bamtofastq/1.4.1  2024/05/06  09:33:41
# 1           abricate/1.0.1  2022/02/08  10:31:47
# 2              abyss/2.2.1  2020/12/10  11:20:09
# 3         admixtools/7.0.2  2024/02/14  10:14:24
# 4          admixture/1.3.0  2024/02/14  10:14:47
# ...                    ...         ...       ...
# 1133          xgboost/0.82  2020/12/10  11:20:09
# 1134           yacrd/1.0.0  2022/11/22  16:27:38
# 1135           yahs/1.2a.2  2024/01/11  11:29:09
# 1136     yak/0.1-r69-dirty  2024/03/20  18:54:06
# 1137      zenodo_get/1.3.2  2021/06/28  09:57:22
#
# [1138 rows x 3 columns]

# %%
# modules=modules[[0]]

# %%
modules["version"]= modules["module_name"].str.split("/").str[1]

# %%
modules["module_name"]= modules["module_name"].str.split("/").str[0]

# %%
modules
# Out:
#          module_name        date      time        version
# 0     10x_bamtofastq  2024/05/06  09:33:41          1.4.1
# 1           abricate  2022/02/08  10:31:47          1.0.1
# 2              abyss  2020/12/10  11:20:09          2.2.1
# 3         admixtools  2024/02/14  10:14:24          7.0.2
# 4          admixture  2024/02/14  10:14:47          1.3.0
# ...              ...         ...       ...            ...
# 1133         xgboost  2020/12/10  11:20:09           0.82
# 1134           yacrd  2022/11/22  16:27:38          1.0.0
# 1135            yahs  2024/01/11  11:29:09         1.2a.2
# 1136             yak  2024/03/20  18:54:06  0.1-r69-dirty
# 1137      zenodo_get  2021/06/28  09:57:22          1.3.2
#
# [1138 rows x 4 columns]

# %%
modules.rename(columns={0: "module"}, inplace=True)
# Out:
# /tmp/ipykernel_3215028/2330748552.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   modules.rename(columns={0: "module"}, inplace=True)

# %%
modules
# Out:
#                        module
# 0        10x_bamtofastq/1.4.1
# 1    alphafold/2.1.1-splitted
# 2   bioconductor-dada2/1.14.0
# 3        biopet-seqstat/1.0.1
# 4        cellranger-arc/2.0.2
# ..                        ...
# 78       ucsc-chainprenet/377
# 79     ucsc-genepredtogtf/377
# 80    ucsc-gff3togenepred/447
# 81       ucsc-netsyntenic/377
# 82       ucsc-wigtobigwig/377
#
# [83 rows x 1 columns]

# %%
# Out:
# /tmp/ipykernel_3215028/1528897044.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   modules["version"]= modules["module"].str.split("/").str[1]

# %%
modules
# Out:
#                        module         version
# 0        10x_bamtofastq/1.4.1           1.4.1
# 1    alphafold/2.1.1-splitted  2.1.1-splitted
# 2   bioconductor-dada2/1.14.0          1.14.0
# 3        biopet-seqstat/1.0.1           1.0.1
# 4        cellranger-arc/2.0.2           2.0.2
# ..                        ...             ...
# 78       ucsc-chainprenet/377             377
# 79     ucsc-genepredtogtf/377             377
# 80    ucsc-gff3togenepred/447             447
# 81       ucsc-netsyntenic/377             377
# 82       ucsc-wigtobigwig/377             377
#
# [83 rows x 2 columns]

# %%
modules["module"] = modules["module"].str.split("/").str[0]

# %%
modules
# Out:
#               module  version
# 0     10x_bamtofastq      NaN
# 1           abricate      NaN
# 2              abyss      NaN
# 3         admixtools      NaN
# 4          admixture      NaN
# ...              ...      ...
# 1133         xgboost      NaN
# 1134           yacrd      NaN
# 1135            yahs      NaN
# 1136             yak      NaN
# 1137      zenodo_get      NaN
#
# [1138 rows x 2 columns]
